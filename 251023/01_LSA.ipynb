# %%
# 라이브러리 로드
from konlpy.tag import Komoran
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd

# %%
# 데이터 로드
df = pd.read_csv('../data/ratings_train.txt', sep='\t')

# %%
# 데이터 결측치를 제외
df.dropna(inplace=True)

# %%
# 독립변수, 종속변수 생성
X = df['document'][:5000]
Y = df['label'][:5000]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42, stratify=Y
)

# %%
print(X_train.shape)
# Out:
# (4000,)

# %% [markdown]
# - 파이프라인 생성
#     - 벡터화(TF-IDF 방식)
#         - 토큰화 함수(komoran 형태소 방식) 포함
#     - LSA
#         - TruncatedSVD() 차원 축소를 사용
#     - Scaler
#         - StandardScaler를 이용
#     - Model
#         - SVC() 모델

# %%
from sklearn.preprocessing import StandardScaler

# %%
# 토큰화 함수
komoran = Komoran()
allow_pos = ['NNP', 'NNG', 'VV', 'VA', 'MAG']

def tokenize(text):
    result = []
    for word, pos in komoran.pos(text):
        if pos in allow_pos:
            result.append(word)
    return result

# 벡터화 객체 생성
vectorizer = TfidfVectorizer(
    # 토큰화 방식
    tokenizer=tokenize,
    lowercase=False,
    min_df=5,
    max_df=0.8,
    ngram_range=(1, 1)
)

# %%
# 차원축소 객체 생성
svd = TruncatedSVD(
    n_components=200,
    random_state=42
)

# %%
# StandardScaler
scaler = StandardScaler(with_mean=True)

# %%
svc = SVC(
    kernel='linear',
    random_state=42,
    probability=False
)

# %%
# 위의 4개의 작업을 하나의 객체로 연결
pipe = Pipeline(
    [
        ('vector', vectorizer),
        ('lsa', svd),
        ('scaler', scaler),
        ('model', svc)
    ]
)

# %%
# 최적의 매개변수를 찾기 위해 매개변수들을 지정
# pipe를 이용하게 되면 pipe step의 객체들의 key__parmaeter : [val1, val2]
grid_params = {
    'vector__ngram_range' : [(1, 1), (1, 2)],
    'lsa__n_components' : [100, 200],
    'model__C' : [1.0, 2.0]
}

# %%
# GridSearchCV를 이용하여 각각 매개변수들을 대입하여 최적의 매개변수를 찾는다
grid = GridSearchCV(
    estimator=pipe,
    param_grid=grid_params,
    cv=2,
    scoring='accuracy',
    verbose=1,
    # n_jobs=-1   # remote error 발생시 주석 처리
)

# %%
grid.fit(X_train, Y_train)
# Out:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('vector',
#                                         TfidfVectorizer(lowercase=False,
#                                                         max_df=0.8, min_df=5,
#                                                         tokenizer=<function tokenize at 0x0000013BB02E4FE0>)),
#                                        ('lsa',
#                                         TruncatedSVD(n_components=200,
#                                                      random_state=42)),
#                                        ('scaler', StandardScaler()),
#                                        ('model',
#                                         SVC(kernel='linear',
#                                             random_state=42))]),
#              param_grid={'lsa__n_components': [100, 200],
#                          'model__C': [1.0, 2.0],
#                          'vector__ngram_range': [(1, 1), (1, 2)]},
#              scoring='accuracy', verbose=1)

# %%
# 최적의 모델을 확인
print("Best Params :", grid.best_params_)
# 최적의 모델의 정확도를 확인
print('Best Acc :', round(grid.best_score_, 4))
# Out:
# Best Params : {'lsa__n_components': 200, 'model__C': 2.0, 'vector__ngram_range': (1, 1)}
# Best Acc : 0.7235

# %%
# 테스트 데이터를 이용하여 정확도 f1score를 확인
# 실무 -> 충분한 모델링 학습을 하고 실전의 데이터를 이용하여 정확도 및 f1score를 확인
# grid에서 최적의 모델을 변수에 저장
best_model = grid.best_estimator_

# %%
# test 데이터셋을 이용하여 예측
best_pred = best_model.predict(X_test)

# %%
# 예측값과 실젯값을 이용하여 정확도 f1score를 확인
best_acc = accuracy_score(best_pred, Y_test)
best_f1 = f1_score(best_pred, Y_test)
print(f"정확도 : {round(best_acc , 3)}, f1 : {round(best_f1, 3)}")
# Out:
# 정확도 : 0.743, f1 : 0.731
