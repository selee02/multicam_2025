# %%
# 라이브러리 설치
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.35.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.6.15 in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (from selenium) (2025.8.3)
# Collecting typing_extensions~=4.14.0 (from selenium)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting websocket-client~=1.8.0 (from selenium)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting attrs>=23.2.0 (from trio~=0.30.0->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting sortedcontainers (from trio~=0.30.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (from trio~=0.30.0->selenium) (3.10)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.30.0->selenium)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.5.0->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pycparser in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.22)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.12.2->selenium)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Downloading selenium-4.35.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------  9.4/9.6 MB 62.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 40.7 MB/s  0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, websocket-client, typing_extensions, sniffio, pysocks, h11, attrs, wsproto, outcome, trio, trio-websocket, selenium
#
#    --- ------------------------------------  1/12 [websocket-client]
#    --- ------------------------------------  1/12 [websocket-client]
#    --- ------------------------------------  1/12 [websocket-client]
#   Attempting uninstall: typing_extensions
#    --- ------------------------------------  1/12 [websocket-client]
#     Found existing installation: typing_extensions 4.15.0
#    --- ------------------------------------  1/12 [websocket-client]
#     Uninstalling typing_extensions-4.15.0:
#    --- ------------------------------------  1/12 [websocket-client]
#    ------ ---------------------------------  2/12 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    ------ ---------------------------------  2/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [sniffio]
#    ---------------- -----------------------  5/12 [h11]
#    -------------------- -------------------  6/12 [attrs]
#    -------------------- -------------------  6/12 [attrs]
#    ----------------------- ----------------  7/12 [wsproto]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------ ---------  9/12 [trio]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ------------------------------------ --- 11/12 [selenium]
#    ---------------------------------------- 12/12 [selenium]
#
# Successfully installed attrs-25.3.0 h11-0.16.0 outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.35.0 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.30.0 trio-websocket-0.12.2 typing_extensions-4.14.1 websocket-client-1.8.0 wsproto-1.2.0

# %%
from selenium import webdriver

# %%
# webdriver -> 웹 브라우져들의 모음
driver = webdriver.Chrome()

# %%
# driver에 url주소를 입력하여 요청 보낸다.
driver.get('http://www.naver.com')

# %%
# driver에서 html 문서를 불러온다.
html_data = driver.page_source

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(html_data, 'html.parser')

# %%
len(soup.find_all('a'))
# Out:
# 159

# %%
# driver에서 특정 속성을 이용하여 태그에 접근하도록 새로운 기능 로드
from selenium.webdriver.common.by import By
# 키보드의 이벤트(ENTER, Back Space, ...)들이 저장되어있는 기능을 로드
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# - find_element()
#     - driver 안에 있는 태그중 조건에 맞는 첫번째 태그를 선택
#     - BeautifulSoup의 find() 함수와 비슷
# - find_elements()
#     - driver 안에 있는 태그 중 조건에 맞는 모든 태그를 선택

# %%
# 검색어창 태그를 선택
# id가 query인 태그 -> id 속성이기 때문에 해당 조건에 맞는 태그는 유일
search_element = driver.find_element(By.ID, 'query')

# %%
# 검색어창에 텍스트 입력
search_element.send_keys('추석')

# %%
# 검색어창에서 키보드 이벤트 ENTER 발생
search_element.send_keys( Keys.ENTER )
