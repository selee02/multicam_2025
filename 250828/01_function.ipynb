# %% [markdown]
# #### 문자열에서 제공하는 내장 함수
# - upper() : 문자열을 모두 대문자로 변경
# - lower() : 문자열을 모두 소문자로 변경
# - swapcase() : 대문자를 소문자로 소문자를 대문자로 변경
# - title() : 단어의 첫글자만 대문자로 변경
# - strip() : 기본적으로는 문자열의 시작과 끝의 존재하는 공백을 제거
#     - rstrip() : 문자열의 끝의 공백을 제거
#     - lstrip() : 문자열의 시작의 공백을 제거
# - replace() : 특정 문자를 찾아서 다른 문자로 치환
# - split() : 특정 문자를 찾아서 문자를 잘라주는 기능 -> 결과 list

# %%
text_a = 'Apple'
text_b = 'apple'

# %%
text_a == text_b
# Out:
# False

# %%
# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면
# 두 개의 데이터의 형태를 같게 만든다.
text_a = text_a.upper()

# %%
text_b = text_b.upper()

# %%
text_a == text_b
# Out:
# True

# %%
text_c = "  Hello world  "

# %%
# lower()
text_c.lower()
# Out:
# '  hello world  '

# %%
# swapcase()
text_c.swapcase()
# Out:
# '  hELLO WORLD  '

# %%
# title()
text_c.title()
# Out:
# '  Hello World  '

# %%
# 좌우의 공백을 제거하는 함수
text_c == "Hello world"
# Out:
# False

# %%
text_c.strip()
# Out:
# 'Hello world'

# %%
text_c.rstrip()
# Out:
# '  Hello world'

# %%
text_c.lstrip()
# Out:
# 'Hello world  '

# %%
print(text_c.lstrip())
print(text_c.strip())
# Out:
# Hello world
# Hello world

# %%
# 문자열을 숫자형으로 변환
# 금액을 숫자로 변경하여 계산
price_1 = '$10.00'
price_2 = '$20.00'

# %%
price_1 + price_2
# Out:
# '$10.00$20.00'

# %%
# error : '$'는 숫자로 변경이 불가능하기 때문에
# float(price_1)

# %%
# '$' 제거하고 숫자로 변경
float(price_1.lstrip('$')) + float(price_2.lstrip('$'))
# Out:
# 30.0

# %%
price_3 = "1,000원"
price_4 = '3,000원'

# %%
# 문자열 마지막의 '원' 문자를 제거
price_3.rstrip('원')
# Out:
# '1,000'

# %%
# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도
# 문자열 사이에 있는 문자를 변경x
# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거
# replace( '특정문자' , '변겅문자' )
int(price_3.replace(',', '').rstrip('원')) + int(price_4.replace(',', '').rstrip('원'))
# Out:
# 4000

# %%
item_1 = '상품A'
item_2 = '상품a'
item_3 = '상 품 a'

# %%
(item_1 == item_2) and (item_2 == item_3)
# Out:
# False

# %%
# item_1을 기준으로 item_2, item_3 데이터를 변경
# item_2에서는 소문자를 대문자로 변경
item_2 = item_2.upper()

# %%
# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경
item_3 = item_3.upper()

# %%
item_3 = item_3.replace(' ', '')

# %%
(item_1 == item_2) and (item_2 == item_3)
# Out:
# True

# %%
# 문자열을 나눠주는 함수 -> split()
# 공백을 기준으로 문자를 나눠주는 함수 -> 인자로 특정 문자를 입력하면 특정 문자로 문자를 나눠준다.
text_1 = 'a b c d'
text_1.split()
# Out:
# ['a', 'b', 'c', 'd']

# %%
text_2 = 'ammbmmc'
text_2.split('m')
# Out:
# ['a', '', 'b', '', 'c']

# %%
# sql query문
query_1 = "select * from table"
query_2 = "SELECT * FROM table"
query_3 = """
    INSERT INTO
    table
    VALUES
    ('a')
"""
query_4 = """
    select
    *
    from
    table
"""

# %%
# query가 select문인가??
find_word = 'select'

query_1[0 : len(find_word)] == find_word
# Out:
# True

# %%
query_2[ : len(find_word)].lower() == find_word
# Out:
# True

# %%
query_4.lstrip()[ : len(find_word)] == find_word
# Out:
# True

# %%
query_1.split()[0] == find_word
# Out:
# True

# %%
query_4.split()[0]
# Out:
# 'select'

# %%
query_2.split()[0].lower()
# Out:
# 'select'

# %%
query_1.startswith(find_word)
# Out:
# True

# %%
query_2.lower().startswith(find_word)
# Out:
# True

# %%
query_4.lstrip().startswith(find_word)
# Out:
# True

# %%
query_3.lstrip().startswith(find_word)
# Out:
# False

# %%
file_list = [
    "/csv/a.csv",
    "/csv/b.txt",
    "/csv/c.csv",
    "/csv/d.json"
]

# %%
# file_list에서 확장자가 csv인 목록만 출력하자
file_list[1].endswith('csv')
# Out:
# False

# %%
# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.
# 비어있는 리스트를 생성
csv_list= []

# for문 list의 원소를 확인
for i in range(len(file_list)) :
    # i에 들어오는 데이터의 의미 : index
    # file_list에 i번째 항목이 csv로 끝나는가?
    if file_list[i].endswith('csv') :
        # 확장자가 csv인 경우 실행되는 부분
        csv_list.append(file_list[i])
print(csv_list)

# for i in file_list:
#   # i에 들어오는 데이터의 의미 : file_list의 원소
#   if i.endswith('csv') :
#       csv_list.append(i)
# Out:
# ['/csv/a.csv', '/csv/c.csv']

# %%
# 함수
# 특정한 행동을 코드로 표현하고 이름 붙이는 작업
# 특정 입력값을 통해서 연산을 하고 결과를 되돌려주는 작업
# python에서 def 키워드를 이용해서 함수를 생성
def func_1() :
    # 결과 되돌려준다
    return 'Hello'

def func_2() :
    print('Hello')

# %%
# 함수 호출
res_1 = func_1()

# %%
res_2 = func_2()
# Out:
# Hello

# %%
res_1
# Out:
# 'Hello'

# %%
res_2

# %%
# 매개변수가 존재하지 않는 함수에 입력값을 사용해서 호출한다면?
# 입력값을 저장할 수 있는 공간이 존재하지 않기 때문에 에러가 발생
# func_1('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 2
#       1 # 매개변수가 존재하지 않는 함수에 입력값을 사용해서 호출한다면?
# ----> 2 func_1('a')
#
# TypeError: func_1() takes 0 positional arguments but 1 was given

# %%
# 매개변수가 존재하는 함수 생성
def func_3(a, b):
    c = a + b
    return c

# %%
func_3(10, 5)
# a = 10
# b = 5
# c = 10 + 5
# c를 되돌려준다
# Out:
# 15

# %%
# 매개변수가 2개인 함수를 호출하면서 인자를 1개만 입력하는 경우??
# 데이터가 입력되는 공간이 2개인데 데이터는 1개만 입력하면 나머지 하나의 공간에 데이터가 없으므로 에러
# func_3(10)

# %%
# print() : 입력 데이터를 출력하는 기능
# sep 매개변수에 입려 데이터를 대입하려면 매개변수명 = data
# 첫번째 매개변수가 가변의 인자를 받는 형태이기 때문에
print('a', 'b', 'c', sep = '\n')
# Out:
# a
# b
# c

# %%
def func_4(a, b = 5):
    # 매개변수는 2개 a,b
    #   a는 함수를 호출할때 필수 입력 공간
    #   b는 선택 입력 공간
    c = a ** b
    return c

# %%
func_4(2)
# a = 2
# b= 5
# c = 2**5
# 32를 되돌려준다.
# Out:
# 32

# %%
func_4(2, 4)
# a = 2
# b = 5
# b = 4
# c = 2 ** 4
# 16 되돌려준다.
# Out:
# 16

# %% [markdown]
# ### 변수의 종료
# - 컴퓨터의 메모리에 데이터가 저장되는 공간에 이름을 붙이는 작업
#
#     - 전역 변수
#         - 전역의 의미 -> 모든 영역
#         - 해당하는 파일 안에서 어디서든 사용이 가능한 변수
#         - globals() 함수를 호출하면 전역 변수의 목록이 확인 가능
#     - 지역 변수
#         - 지역의 의미 -> 특정 영역
#         - 함수나 클래스 안에서만 사용이 가능한 변수
#         - 함수에서 값을 되돌려주는 행동(return) 뒤에는 함수에서 사용된 변수들은 외부에서는 사용이 불가능

# %%
# 모든 영역에서 사용할 수 있는 변수의 목록 확인
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "text_a = 'Apple'\ntext_b = 'apple'",
#   'text_a == text_b',
#   '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a.pper()',
#   '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a.upper()',
#   '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a = text_a.upper()',
#   'text_a',
#   'text_b = text_b.upper()',
#   'text_b = text_b.upper()',
#   'text_a == text_b',
#   'text_c = "  Hello world  "',
#   '# lower()\ntext_c.lower()',
#   '# swapcase()\ntext_c.swapcase()',
#   '# title()\ntext_c.title()',
#   '# 좌우의 공백을 제거하는 함수\ntext_c == "Hello world"',
#   'text_c.strip()',
#   'text_c.rstrip()',
#   'text_c.lstrip()',
#   'print(text_c.lstrip)\nprint(text_c.strip)',
#   'print(text_c.lstrip())\nprint(text_c.strip())',
#   "# 문자열을 숫자형으로 변환\n# 금액을 숫자로 변경하여 계산\nprice_1 = '$10.00'\nprice_2 = '$20.00'",
#   'price_1 + price_2',
#   'int(price_1)',
#   'float(price_1)',
#   "# error : '$'는 숫자로 변경이 불가능하기 때문에\n# float(price_1)",
#   "# '$' 제거하고 숫자로 변경\nprice_1.lstrip('$')",
#   "# '$' 제거하고 숫자로 변경\nfloat(price_1.lstrip('$'))",
#   "# '$' 제거하고 숫자로 변경\nfloat(price_1.lstrip('$')) + float(price_2.lstrip('$'))",
#   'price_3 = "1,000원"\nprice_4 = \'3,000원\'',
#   "# 문자열 마지막의 '원' 문자를 제거\nfloat(prcie_3.rstrip('원'))",
#   "# 문자열 마지막의 '원' 문자를 제거\nfloat(price_3.rstrip('원'))",
#   "# 문자열 마지막의 '원' 문자를 제거\nint(price_3.rstrip('원'))",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '')",
#   "# 문자열 마지막의 '원' 문자를 제거\nprice_3.rstrip('원')",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '')",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '').rstrip('원')",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nint(price_3.replace(',', '').rstrip('원'))",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nint(price_3.replace(',', '').rstrip('원')) + int(price_4.replace(',', '').rstrip('원'))",
#   "item_1 = '상품A'\nitem_2 = '상품a'\nitem_3 = '상 품 a'",
#   '(item_1 == item_2) and (item_2 == item_3)',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_upper()',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_1.upper()',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_2.upper()',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_2 = item_2.upper()',
#   '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3.ㅕㅔㅔㄷㄱ()',
#   '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3.upper()',
#   '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3 = item_3.upper()',
#   "irem_3.replace(' ', '')",
#   "irtem_3.replace(' ', '')",
#   "item_3.replace(' ', '')",
#   '(item_1 == item_2) and (item_2 == item_3)',
#   "item_3 = item_3.replace(' ', '')",
#   "item_3 = item_3.replace(' ', '')",
#   '(item_1 == item_2) and (item_2 == item_3)',
#   "# 문자열을 나눠주는 함수 -> split()\n# 공백을 기준으로 문자를 나눠주는 함수 -> 인자로 특정 문자를 입력하면 특정 문자로 문자를 나눠준다.\ntext_1 = 'a b c d'\ntext_1.split()",
#   "text_2 = 'ammbmmc'",
#   "text_2 = 'ammbmmc'\ntext_2.split('mm')",
#   "text_2 = 'ammbmmc'\ntext_2.split('m')",
#   "text_2 = 'ammbmmcm'\ntext_2.split('mm')",
#   "text_2 = 'ammbmmcm'\ntext_2.split('m')",
#   "text_2 = 'ammbmmc'\ntext_2.split('m')",
#   '# sql query문\nquery_1 = "select * from table"\nquery_2 = "SELECT * FROM table"\nquery_3 = """\n    INSERT INTO\n    table\n    VALUES\n    (\'a\')\n"""',
#   '# query가 select문인가??',
#   'len("select")',
#   "# query가 select문인가??\nfind_word = 'select'\n\nquery_1[0 : len(find_word)] == find_word",
#   'query_2[ : len(find_word)] == find_word',
#   'query_2[ : len(find_word)].lower() == find_word',
#   'query_4[ : len(find_word)]',
#   '# sql query문\nquery_1 = "select * from table"\nquery_2 = "SELECT * FROM table"\nquery_3 = """\n    INSERT INTO\n    table\n    VALUES\n    (\'a\')\n"""\nquery_4 = """\n    select\n    *\n    from\n    table\n"""',
#   "# query가 select문인가??\nfind_word = 'select'\n\nquery_1[0 : len(find_word)] == find_word",
#   'query_2[ : len(find_word)].lower() == find_word',
#   'query_4[ : len(find_word)]',
#   'query_4.lstrip()[ : len(find_word)]',
#   'query_4.lstrip()[ : len(find_word)] == find_word',
#   'query_1.split()',
#   'query_1.split()[0]',
#   'query_1.split()[0] == find_word',
#   'query_4.split()',
#   'query_4.split()[0]',
#   'query_2.split()',
#   'query_2.split().lower()',
#   'query_2.split()[0].lower()',
#   'query_1.startswith(find_word)',
#   'query_2.lower().startswitch(find_word)',
#   'query_2.lower().startswith(find_word)',
#   'query_4.startswith(find_wird',
#   'query_4.startswith(find_word)',
#   'query_4.lstrip().startswith(find_word)',
#   'query_3.startswith(find_word)',
#   'query_3.lstrip().startswith(find_word)',
#   'file_list = [\n    "/csv/a.csv",\n    "/csv/b.txt",\n    "/csv/c.csv",\n    "/csv/d.json"\n]',
#   '# file_list에서 확장자가 csv인 목록만 출력하자\nfile_lisr[0]',
#   '# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[0]',
#   "# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[0].endswith('csv')",
#   "# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[1].endswith('csv')",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].ednswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') == True:\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n#   # i에 들어오는 데이터의 의미 : file_list의 원소\n#   if i.endswith('csv') :\n#       csv_list.append(i)",
#   "# 함수\n# 특정한 행동을 코드로 표현하고 이름 붙이는 작업\n# 특정 입력값을 통해서 연산을 하고 결과를 되돌려주는 작업\n# python에서 def 키워드를 이용해서 함수를 생성\ndef func_1() :\n    # 결과 되돌려준다\n    return 'Hello'\n\ndef func_2() :\n    print('Heollo')",
#   "# 함수\n# 특정한 행동을 코드로 표현하고 이름 붙이는 작업\n# 특정 입력값을 통해서 연산을 하고 결과를 되돌려주는 작업\n# python에서 def 키워드를 이용해서 함수를 생성\ndef func_1() :\n    # 결과 되돌려준다\n    return 'Hello'\n\ndef func_2() :\n    print('Hello')",
#   '# 함수 호출\nfunc_1',
#   '# 함수 호출\nfunc_1()',
#   'func_2()',
#   '# 함수 호출\nres_1 = func_1()',
#   'res_2 = func_2()',
#   'res_1',
#   'res_2',
#   'type(res_2)',
#   "# 매개변수가 존재하지 않는 함수에 입력값을 사용해서 호출한다면?\nfunc_1('a')",
#   '# 매개변수가 존재하는 함수 생성\ndef func_3(a, b):\n    c = a + b\n    return c',
#   'func_3(10, 5)\n# a = 10\n# b = 5\n# c = 10 + 5\n# c를 되돌려준다',
#   '# 매개변수가 2개인 함수를 호출하면서 인자를 1개만 입력하는 경우??\nfunc_3(10)',
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a')",
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c')",
#   'print()',
#   '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', sep = ",")',
#   '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', end = ",")',
#   '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', end="-")\nprint(\'d\', \'e\', \'f\')',
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', '\\n')",
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c')",
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', sep = '\\n')",
#   '# 매개변수가 2개인 함수를 호출하면서 인자를 1개만 입력하는 경우??\n# 데이터가 입력되는 공간이 2개인데 데이터는 1개만 입력하면 나머지 하나의 공간에 데이터가 없으므로 에러\n# func_3(10)',
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', sep = '\\n')",
#   "# print() : 입력 데이터를 출력하는 기능\n# sep 매개변수에 입려 데이터를 대입하려면 매개변수명 = data\n# 첫번째 매개변수가 가변의 인자를 받는 형태이기 때문에\nprint('a', 'b', 'c', sep = '\\n')",
#   'def func_4(a, b = 5):\n    # 매개변수는 2개 a,b\n    #   a는 함수를 호출할때 필수 입력 공간\n    #   b는 선택 입력 공간\n    c = a ** b\n    return c',
#   'func_4(2)\n# a = 2\n# b= 5\n# c = 2**5\n# 32를 되돌려준다.',
#   'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4',
#   'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4\n# 16',
#   '# 모든 영역에서 사용할 수 있는 변수의 목록 확인\nglobals()'],
#  '_oh': {2: False,
#   4: 'APPLE',
#   6: 'APPLE',
#   9: True,
#   11: '  hello world  ',
#   12: '  hELLO WORLD  ',
#   13: '  Hello World  ',
#   14: False,
#   15: 'Hello world',
#   16: '  Hello world',
#   17: 'Hello world  ',
#   21: '$10.00$20.00',
#   25: '10.00',
#   26: 10.0,
#   27: 30.0,
#   32: '1000원',
#   33: '1,000',
#   34: '1000원',
#   35: '1000',
#   36: 1000,
#   37: 4000,
#   39: False,
#   41: '상품A',
#   42: '상품A',
#   45: '상 품 A',
#   49: '상품A',
#   50: False,
#   53: True,
#   54: ['a', 'b', 'c', 'd'],
#   56: ['a', 'b', 'c'],
#   57: ['a', '', 'b', '', 'c'],
#   58: ['a', 'b', 'cm'],
#   59: ['a', '', 'b', '', 'c', ''],
#   60: ['a', '', 'b', '', 'c'],
#   63: 6,
#   64: True,
#   65: False,
#   66: True,
#   69: True,
#   70: True,
#   71: '\n    s',
#   72: 'select',
#   73: True,
#   74: ['select', '*', 'from', 'table'],
#   75: 'select',
#   76: True,
#   77: ['select', '*', 'from', 'table'],
#   78: 'select',
#   79: ['SELECT', '*', 'FROM', 'table'],
#   81: 'select',
#   82: True,
#   84: True,
#   86: False,
#   87: True,
#   88: False,
#   89: False,
#   92: '/csv/a.csv',
#   93: True,
#   94: False,
#   101: <function __main__.func_1()>,
#   102: 'Hello',
#   106: 'Hello',
#   108: NoneType,
#   111: 15,
#   126: 32,
#   127: 16,
#   128: 16},
#  '_dh': [WindowsPath('c:/python/multicam/250828')],
#  'In': ['',
#   "text_a = 'Apple'\ntext_b = 'apple'",
#   'text_a == text_b',
#   '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a.pper()',
#   '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a.upper()',
#   '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a = text_a.upper()',
#   'text_a',
#   'text_b = text_b.upper()',
#   'text_b = text_b.upper()',
#   'text_a == text_b',
#   'text_c = "  Hello world  "',
#   '# lower()\ntext_c.lower()',
#   '# swapcase()\ntext_c.swapcase()',
#   '# title()\ntext_c.title()',
#   '# 좌우의 공백을 제거하는 함수\ntext_c == "Hello world"',
#   'text_c.strip()',
#   'text_c.rstrip()',
#   'text_c.lstrip()',
#   'print(text_c.lstrip)\nprint(text_c.strip)',
#   'print(text_c.lstrip())\nprint(text_c.strip())',
#   "# 문자열을 숫자형으로 변환\n# 금액을 숫자로 변경하여 계산\nprice_1 = '$10.00'\nprice_2 = '$20.00'",
#   'price_1 + price_2',
#   'int(price_1)',
#   'float(price_1)',
#   "# error : '$'는 숫자로 변경이 불가능하기 때문에\n# float(price_1)",
#   "# '$' 제거하고 숫자로 변경\nprice_1.lstrip('$')",
#   "# '$' 제거하고 숫자로 변경\nfloat(price_1.lstrip('$'))",
#   "# '$' 제거하고 숫자로 변경\nfloat(price_1.lstrip('$')) + float(price_2.lstrip('$'))",
#   'price_3 = "1,000원"\nprice_4 = \'3,000원\'',
#   "# 문자열 마지막의 '원' 문자를 제거\nfloat(prcie_3.rstrip('원'))",
#   "# 문자열 마지막의 '원' 문자를 제거\nfloat(price_3.rstrip('원'))",
#   "# 문자열 마지막의 '원' 문자를 제거\nint(price_3.rstrip('원'))",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '')",
#   "# 문자열 마지막의 '원' 문자를 제거\nprice_3.rstrip('원')",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '')",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '').rstrip('원')",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nint(price_3.replace(',', '').rstrip('원'))",
#   "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nint(price_3.replace(',', '').rstrip('원')) + int(price_4.replace(',', '').rstrip('원'))",
#   "item_1 = '상품A'\nitem_2 = '상품a'\nitem_3 = '상 품 a'",
#   '(item_1 == item_2) and (item_2 == item_3)',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_upper()',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_1.upper()',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_2.upper()',
#   '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_2 = item_2.upper()',
#   '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3.ㅕㅔㅔㄷㄱ()',
#   '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3.upper()',
#   '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3 = item_3.upper()',
#   "irem_3.replace(' ', '')",
#   "irtem_3.replace(' ', '')",
#   "item_3.replace(' ', '')",
#   '(item_1 == item_2) and (item_2 == item_3)',
#   "item_3 = item_3.replace(' ', '')",
#   "item_3 = item_3.replace(' ', '')",
#   '(item_1 == item_2) and (item_2 == item_3)',
#   "# 문자열을 나눠주는 함수 -> split()\n# 공백을 기준으로 문자를 나눠주는 함수 -> 인자로 특정 문자를 입력하면 특정 문자로 문자를 나눠준다.\ntext_1 = 'a b c d'\ntext_1.split()",
#   "text_2 = 'ammbmmc'",
#   "text_2 = 'ammbmmc'\ntext_2.split('mm')",
#   "text_2 = 'ammbmmc'\ntext_2.split('m')",
#   "text_2 = 'ammbmmcm'\ntext_2.split('mm')",
#   "text_2 = 'ammbmmcm'\ntext_2.split('m')",
#   "text_2 = 'ammbmmc'\ntext_2.split('m')",
#   '# sql query문\nquery_1 = "select * from table"\nquery_2 = "SELECT * FROM table"\nquery_3 = """\n    INSERT INTO\n    table\n    VALUES\n    (\'a\')\n"""',
#   '# query가 select문인가??',
#   'len("select")',
#   "# query가 select문인가??\nfind_word = 'select'\n\nquery_1[0 : len(find_word)] == find_word",
#   'query_2[ : len(find_word)] == find_word',
#   'query_2[ : len(find_word)].lower() == find_word',
#   'query_4[ : len(find_word)]',
#   '# sql query문\nquery_1 = "select * from table"\nquery_2 = "SELECT * FROM table"\nquery_3 = """\n    INSERT INTO\n    table\n    VALUES\n    (\'a\')\n"""\nquery_4 = """\n    select\n    *\n    from\n    table\n"""',
#   "# query가 select문인가??\nfind_word = 'select'\n\nquery_1[0 : len(find_word)] == find_word",
#   'query_2[ : len(find_word)].lower() == find_word',
#   'query_4[ : len(find_word)]',
#   'query_4.lstrip()[ : len(find_word)]',
#   'query_4.lstrip()[ : len(find_word)] == find_word',
#   'query_1.split()',
#   'query_1.split()[0]',
#   'query_1.split()[0] == find_word',
#   'query_4.split()',
#   'query_4.split()[0]',
#   'query_2.split()',
#   'query_2.split().lower()',
#   'query_2.split()[0].lower()',
#   'query_1.startswith(find_word)',
#   'query_2.lower().startswitch(find_word)',
#   'query_2.lower().startswith(find_word)',
#   'query_4.startswith(find_wird',
#   'query_4.startswith(find_word)',
#   'query_4.lstrip().startswith(find_word)',
#   'query_3.startswith(find_word)',
#   'query_3.lstrip().startswith(find_word)',
#   'file_list = [\n    "/csv/a.csv",\n    "/csv/b.txt",\n    "/csv/c.csv",\n    "/csv/d.json"\n]',
#   '# file_list에서 확장자가 csv인 목록만 출력하자\nfile_lisr[0]',
#   '# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[0]',
#   "# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[0].endswith('csv')",
#   "# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[1].endswith('csv')",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].ednswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') == True:\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#   "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n#   # i에 들어오는 데이터의 의미 : file_list의 원소\n#   if i.endswith('csv') :\n#       csv_list.append(i)",
#   "# 함수\n# 특정한 행동을 코드로 표현하고 이름 붙이는 작업\n# 특정 입력값을 통해서 연산을 하고 결과를 되돌려주는 작업\n# python에서 def 키워드를 이용해서 함수를 생성\ndef func_1() :\n    # 결과 되돌려준다\n    return 'Hello'\n\ndef func_2() :\n    print('Heollo')",
#   "# 함수\n# 특정한 행동을 코드로 표현하고 이름 붙이는 작업\n# 특정 입력값을 통해서 연산을 하고 결과를 되돌려주는 작업\n# python에서 def 키워드를 이용해서 함수를 생성\ndef func_1() :\n    # 결과 되돌려준다\n    return 'Hello'\n\ndef func_2() :\n    print('Hello')",
#   '# 함수 호출\nfunc_1',
#   '# 함수 호출\nfunc_1()',
#   'func_2()',
#   '# 함수 호출\nres_1 = func_1()',
#   'res_2 = func_2()',
#   'res_1',
#   'res_2',
#   'type(res_2)',
#   "# 매개변수가 존재하지 않는 함수에 입력값을 사용해서 호출한다면?\nfunc_1('a')",
#   '# 매개변수가 존재하는 함수 생성\ndef func_3(a, b):\n    c = a + b\n    return c',
#   'func_3(10, 5)\n# a = 10\n# b = 5\n# c = 10 + 5\n# c를 되돌려준다',
#   '# 매개변수가 2개인 함수를 호출하면서 인자를 1개만 입력하는 경우??\nfunc_3(10)',
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a')",
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c')",
#   'print()',
#   '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', sep = ",")',
#   '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', end = ",")',
#   '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', end="-")\nprint(\'d\', \'e\', \'f\')',
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', '\\n')",
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c')",
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', sep = '\\n')",
#   '# 매개변수가 2개인 함수를 호출하면서 인자를 1개만 입력하는 경우??\n# 데이터가 입력되는 공간이 2개인데 데이터는 1개만 입력하면 나머지 하나의 공간에 데이터가 없으므로 에러\n# func_3(10)',
#   "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', sep = '\\n')",
#   "# print() : 입력 데이터를 출력하는 기능\n# sep 매개변수에 입려 데이터를 대입하려면 매개변수명 = data\n# 첫번째 매개변수가 가변의 인자를 받는 형태이기 때문에\nprint('a', 'b', 'c', sep = '\\n')",
#   'def func_4(a, b = 5):\n    # 매개변수는 2개 a,b\n    #   a는 함수를 호출할때 필수 입력 공간\n    #   b는 선택 입력 공간\n    c = a ** b\n    return c',
#   'func_4(2)\n# a = 2\n# b= 5\n# c = 2**5\n# 32를 되돌려준다.',
#   'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4',
#   'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4\n# 16',
#   '# 모든 영역에서 사용할 수 있는 변수의 목록 확인\nglobals()'],
#  'Out': {2: False,
#   4: 'APPLE',
#   6: 'APPLE',
#   9: True,
#   11: '  hello world  ',
#   12: '  hELLO WORLD  ',
#   13: '  Hello World  ',
#   14: False,
#   15: 'Hello world',
#   16: '  Hello world',
#   17: 'Hello world  ',
#   21: '$10.00$20.00',
#   25: '10.00',
#   26: 10.0,
#   27: 30.0,
#   32: '1000원',
#   33: '1,000',
#   34: '1000원',
#   35: '1000',
#   36: 1000,
#   37: 4000,
#   39: False,
#   41: '상품A',
#   42: '상품A',
#   45: '상 품 A',
#   49: '상품A',
#   50: False,
#   53: True,
#   54: ['a', 'b', 'c', 'd'],
#   56: ['a', 'b', 'c'],
#   57: ['a', '', 'b', '', 'c'],
#   58: ['a', 'b', 'cm'],
#   59: ['a', '', 'b', '', 'c', ''],
#   60: ['a', '', 'b', '', 'c'],
#   63: 6,
#   64: True,
#   65: False,
#   66: True,
#   69: True,
#   70: True,
#   71: '\n    s',
#   72: 'select',
#   73: True,
#   74: ['select', '*', 'from', 'table'],
#   75: 'select',
#   76: True,
#   77: ['select', '*', 'from', 'table'],
#   78: 'select',
#   79: ['SELECT', '*', 'FROM', 'table'],
#   81: 'select',
#   82: True,
#   84: True,
#   86: False,
#   87: True,
#   88: False,
#   89: False,
#   92: '/csv/a.csv',
#   93: True,
#   94: False,
#   101: <function __main__.func_1()>,
#   102: 'Hello',
#   106: 'Hello',
#   108: NoneType,
#   111: 15,
#   126: 32,
#   127: 16,
#   128: 16},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000019AFD1EF380>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x19afd284c20>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x19afd284c20>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': 16,
#  '__': 16,
#  '___': 32,
#  '__vsc_ipynb_file__': 'c:\\python\\multicam\\250828\\01_function.ipynb',
#  '_i': 'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4\n# 16',
#  '_ii': 'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4',
#  '_iii': 'func_4(2)\n# a = 2\n# b= 5\n# c = 2**5\n# 32를 되돌려준다.',
#  '_i1': "text_a = 'Apple'\ntext_b = 'apple'",
#  'text_a': 'APPLE',
#  'text_b': 'APPLE',
#  '_i2': 'text_a == text_b',
#  '_2': False,
#  '_i3': '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a.pper()',
#  '_i4': '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a.upper()',
#  '_4': 'APPLE',
#  '_i5': '# text_a와 text_b를 비교했을 때 같다라는 결과를 만드려면\n# 두 개의 데이터의 형태를 같게 만든다.\ntext_a = text_a.upper()',
#  '_i6': 'text_a',
#  '_6': 'APPLE',
#  '_i7': 'text_b = text_b.upper()',
#  '_i8': 'text_b = text_b.upper()',
#  '_i9': 'text_a == text_b',
#  '_9': True,
#  '_i10': 'text_c = "  Hello world  "',
#  'text_c': '  Hello world  ',
#  '_i11': '# lower()\ntext_c.lower()',
#  '_11': '  hello world  ',
#  '_i12': '# swapcase()\ntext_c.swapcase()',
#  '_12': '  hELLO WORLD  ',
#  '_i13': '# title()\ntext_c.title()',
#  '_13': '  Hello World  ',
#  '_i14': '# 좌우의 공백을 제거하는 함수\ntext_c == "Hello world"',
#  '_14': False,
#  '_i15': 'text_c.strip()',
#  '_15': 'Hello world',
#  '_i16': 'text_c.rstrip()',
#  '_16': '  Hello world',
#  '_i17': 'text_c.lstrip()',
#  '_17': 'Hello world  ',
#  '_i18': 'print(text_c.lstrip)\nprint(text_c.strip)',
#  '_i19': 'print(text_c.lstrip())\nprint(text_c.strip())',
#  '_i20': "# 문자열을 숫자형으로 변환\n# 금액을 숫자로 변경하여 계산\nprice_1 = '$10.00'\nprice_2 = '$20.00'",
#  'price_1': '$10.00',
#  'price_2': '$20.00',
#  '_i21': 'price_1 + price_2',
#  '_21': '$10.00$20.00',
#  '_i22': 'int(price_1)',
#  '_i23': 'float(price_1)',
#  '_i24': "# error : '$'는 숫자로 변경이 불가능하기 때문에\n# float(price_1)",
#  '_i25': "# '$' 제거하고 숫자로 변경\nprice_1.lstrip('$')",
#  '_25': '10.00',
#  '_i26': "# '$' 제거하고 숫자로 변경\nfloat(price_1.lstrip('$'))",
#  '_26': 10.0,
#  '_i27': "# '$' 제거하고 숫자로 변경\nfloat(price_1.lstrip('$')) + float(price_2.lstrip('$'))",
#  '_27': 30.0,
#  '_i28': 'price_3 = "1,000원"\nprice_4 = \'3,000원\'',
#  'price_3': '1,000원',
#  'price_4': '3,000원',
#  '_i29': "# 문자열 마지막의 '원' 문자를 제거\nfloat(prcie_3.rstrip('원'))",
#  '_i30': "# 문자열 마지막의 '원' 문자를 제거\nfloat(price_3.rstrip('원'))",
#  '_i31': "# 문자열 마지막의 '원' 문자를 제거\nint(price_3.rstrip('원'))",
#  '_i32': "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '')",
#  '_32': '1000원',
#  '_i33': "# 문자열 마지막의 '원' 문자를 제거\nprice_3.rstrip('원')",
#  '_33': '1,000',
#  '_i34': "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '')",
#  '_34': '1000원',
#  '_i35': "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nprice_3.replace(',', '').rstrip('원')",
#  '_35': '1000',
#  '_i36': "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nint(price_3.replace(',', '').rstrip('원'))",
#  '_36': 1000,
#  '_i37': "# strip() 함수는 문자의 시작과 끝의 데이터를 제거하는 용도\n# 문자열 사이에 있는 문자를 변경x\n# replace() : 특정문자를 치환 -> 문자를 변경, 문자를 제거\n# replace( '특정문자' , '변겅문자' )\nint(price_3.replace(',', '').rstrip('원')) + int(price_4.replace(',', '').rstrip('원'))",
#  '_37': 4000,
#  '_i38': "item_1 = '상품A'\nitem_2 = '상품a'\nitem_3 = '상 품 a'",
#  'item_1': '상품A',
#  'item_2': '상품A',
#  'item_3': '상품A',
#  '_i39': '(item_1 == item_2) and (item_2 == item_3)',
#  '_39': False,
#  '_i40': '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_upper()',
#  '_i41': '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_1.upper()',
#  '_41': '상품A',
#  '_i42': '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_2.upper()',
#  '_42': '상품A',
#  '_i43': '# item_1을 기준으로 item_2, item_3 데이터를 변경\n# item_2에서는 소문자를 대문자로 변경\nitem_2 = item_2.upper()',
#  '_i44': '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3.ㅕㅔㅔㄷㄱ()',
#  '_i45': '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3.upper()',
#  '_45': '상 품 A',
#  '_i46': '# item_3는 문자열 사이에 존재하는 공백을 제거 -> 문자열을 대문자로 변경\nitem_3 = item_3.upper()',
#  '_i47': "irem_3.replace(' ', '')",
#  '_i48': "irtem_3.replace(' ', '')",
#  '_i49': "item_3.replace(' ', '')",
#  '_49': '상품A',
#  '_i50': '(item_1 == item_2) and (item_2 == item_3)',
#  '_50': False,
#  '_i51': "item_3 = item_3.replace(' ', '')",
#  '_i52': "item_3 = item_3.replace(' ', '')",
#  '_i53': '(item_1 == item_2) and (item_2 == item_3)',
#  '_53': True,
#  '_i54': "# 문자열을 나눠주는 함수 -> split()\n# 공백을 기준으로 문자를 나눠주는 함수 -> 인자로 특정 문자를 입력하면 특정 문자로 문자를 나눠준다.\ntext_1 = 'a b c d'\ntext_1.split()",
#  'text_1': 'a b c d',
#  '_54': ['a', 'b', 'c', 'd'],
#  '_i55': "text_2 = 'ammbmmc'",
#  'text_2': 'ammbmmc',
#  '_i56': "text_2 = 'ammbmmc'\ntext_2.split('mm')",
#  '_56': ['a', 'b', 'c'],
#  '_i57': "text_2 = 'ammbmmc'\ntext_2.split('m')",
#  '_57': ['a', '', 'b', '', 'c'],
#  '_i58': "text_2 = 'ammbmmcm'\ntext_2.split('mm')",
#  '_58': ['a', 'b', 'cm'],
#  '_i59': "text_2 = 'ammbmmcm'\ntext_2.split('m')",
#  '_59': ['a', '', 'b', '', 'c', ''],
#  '_i60': "text_2 = 'ammbmmc'\ntext_2.split('m')",
#  '_60': ['a', '', 'b', '', 'c'],
#  '_i61': '# sql query문\nquery_1 = "select * from table"\nquery_2 = "SELECT * FROM table"\nquery_3 = """\n    INSERT INTO\n    table\n    VALUES\n    (\'a\')\n"""',
#  'query_1': 'select * from table',
#  'query_2': 'SELECT * FROM table',
#  'query_3': "\n    INSERT INTO\n    table\n    VALUES\n    ('a')\n",
#  '_i62': '# query가 select문인가??',
#  '_i63': 'len("select")',
#  '_63': 6,
#  '_i64': "# query가 select문인가??\nfind_word = 'select'\n\nquery_1[0 : len(find_word)] == find_word",
#  'find_word': 'select',
#  '_64': True,
#  '_i65': 'query_2[ : len(find_word)] == find_word',
#  '_65': False,
#  '_i66': 'query_2[ : len(find_word)].lower() == find_word',
#  '_66': True,
#  '_i67': 'query_4[ : len(find_word)]',
#  '_i68': '# sql query문\nquery_1 = "select * from table"\nquery_2 = "SELECT * FROM table"\nquery_3 = """\n    INSERT INTO\n    table\n    VALUES\n    (\'a\')\n"""\nquery_4 = """\n    select\n    *\n    from\n    table\n"""',
#  'query_4': '\n    select\n    *\n    from\n    table\n',
#  '_i69': "# query가 select문인가??\nfind_word = 'select'\n\nquery_1[0 : len(find_word)] == find_word",
#  '_69': True,
#  '_i70': 'query_2[ : len(find_word)].lower() == find_word',
#  '_70': True,
#  '_i71': 'query_4[ : len(find_word)]',
#  '_71': '\n    s',
#  '_i72': 'query_4.lstrip()[ : len(find_word)]',
#  '_72': 'select',
#  '_i73': 'query_4.lstrip()[ : len(find_word)] == find_word',
#  '_73': True,
#  '_i74': 'query_1.split()',
#  '_74': ['select', '*', 'from', 'table'],
#  '_i75': 'query_1.split()[0]',
#  '_75': 'select',
#  '_i76': 'query_1.split()[0] == find_word',
#  '_76': True,
#  '_i77': 'query_4.split()',
#  '_77': ['select', '*', 'from', 'table'],
#  '_i78': 'query_4.split()[0]',
#  '_78': 'select',
#  '_i79': 'query_2.split()',
#  '_79': ['SELECT', '*', 'FROM', 'table'],
#  '_i80': 'query_2.split().lower()',
#  '_i81': 'query_2.split()[0].lower()',
#  '_81': 'select',
#  '_i82': 'query_1.startswith(find_word)',
#  '_82': True,
#  '_i83': 'query_2.lower().startswitch(find_word)',
#  '_i84': 'query_2.lower().startswith(find_word)',
#  '_84': True,
#  '_i85': 'query_4.startswith(find_wird',
#  '_i86': 'query_4.startswith(find_word)',
#  '_86': False,
#  '_i87': 'query_4.lstrip().startswith(find_word)',
#  '_87': True,
#  '_i88': 'query_3.startswith(find_word)',
#  '_88': False,
#  '_i89': 'query_3.lstrip().startswith(find_word)',
#  '_89': False,
#  '_i90': 'file_list = [\n    "/csv/a.csv",\n    "/csv/b.txt",\n    "/csv/c.csv",\n    "/csv/d.json"\n]',
#  'file_list': ['/csv/a.csv', '/csv/b.txt', '/csv/c.csv', '/csv/d.json'],
#  '_i91': '# file_list에서 확장자가 csv인 목록만 출력하자\nfile_lisr[0]',
#  '_i92': '# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[0]',
#  '_92': '/csv/a.csv',
#  '_i93': "# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[0].endswith('csv')",
#  '_93': True,
#  '_i94': "# file_list에서 확장자가 csv인 목록만 출력하자\nfile_list[1].endswith('csv')",
#  '_94': False,
#  '_i95': "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].ednswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#  'csv_list': ['/csv/a.csv', '/csv/c.csv'],
#  'i': 3,
#  '_i96': "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#  '_i97': "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') == True:\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n    # i에 들어오는 데이터의 의미 : file_list의 원소",
#  '_i98': "# 반복문을 이용하여 file_list에서 csv 확장인 파일만 새로운 목록을 만든다.\n# 비어있는 리스트를 생성\ncsv_list= []\n\n# for문 list의 원소를 확인\nfor i in range(len(file_list)) :\n    # i에 들어오는 데이터의 의미 : index\n    # file_list에 i번째 항목이 csv로 끝나는가?\n    if file_list[i].endswith('csv') :\n        # 확장자가 csv인 경우 실행되는 부분\n        csv_list.append(file_list[i])\nprint(csv_list)\n\n# for i in file_list:\n#   # i에 들어오는 데이터의 의미 : file_list의 원소\n#   if i.endswith('csv') :\n#       csv_list.append(i)",
#  '_i99': "# 함수\n# 특정한 행동을 코드로 표현하고 이름 붙이는 작업\n# 특정 입력값을 통해서 연산을 하고 결과를 되돌려주는 작업\n# python에서 def 키워드를 이용해서 함수를 생성\ndef func_1() :\n    # 결과 되돌려준다\n    return 'Hello'\n\ndef func_2() :\n    print('Heollo')",
#  'func_1': <function __main__.func_1()>,
#  'func_2': <function __main__.func_2()>,
#  '_i100': "# 함수\n# 특정한 행동을 코드로 표현하고 이름 붙이는 작업\n# 특정 입력값을 통해서 연산을 하고 결과를 되돌려주는 작업\n# python에서 def 키워드를 이용해서 함수를 생성\ndef func_1() :\n    # 결과 되돌려준다\n    return 'Hello'\n\ndef func_2() :\n    print('Hello')",
#  '_i101': '# 함수 호출\nfunc_1',
#  '_101': <function __main__.func_1()>,
#  '_i102': '# 함수 호출\nfunc_1()',
#  '_102': 'Hello',
#  '_i103': 'func_2()',
#  '_i104': '# 함수 호출\nres_1 = func_1()',
#  'res_1': 'Hello',
#  '_i105': 'res_2 = func_2()',
#  'res_2': None,
#  '_i106': 'res_1',
#  '_106': 'Hello',
#  '_i107': 'res_2',
#  '_i108': 'type(res_2)',
#  '_108': NoneType,
#  '_i109': "# 매개변수가 존재하지 않는 함수에 입력값을 사용해서 호출한다면?\nfunc_1('a')",
#  '_i110': '# 매개변수가 존재하는 함수 생성\ndef func_3(a, b):\n    c = a + b\n    return c',
#  'func_3': <function __main__.func_3(a, b)>,
#  '_i111': 'func_3(10, 5)\n# a = 10\n# b = 5\n# c = 10 + 5\n# c를 되돌려준다',
#  '_111': 15,
#  '_i112': '# 매개변수가 2개인 함수를 호출하면서 인자를 1개만 입력하는 경우??\nfunc_3(10)',
#  '_i113': "# print() : 입력 데이터를 출력하는 기능\nprint('a')",
#  '_i114': "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c')",
#  '_i115': 'print()',
#  '_i116': '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', sep = ",")',
#  '_i117': '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', end = ",")',
#  '_i118': '# print() : 입력 데이터를 출력하는 기능\nprint(\'a\', \'b\', \'c\', end="-")\nprint(\'d\', \'e\', \'f\')',
#  '_i119': "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', '\\n')",
#  '_i120': "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c')",
#  '_i121': "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', sep = '\\n')",
#  '_i122': '# 매개변수가 2개인 함수를 호출하면서 인자를 1개만 입력하는 경우??\n# 데이터가 입력되는 공간이 2개인데 데이터는 1개만 입력하면 나머지 하나의 공간에 데이터가 없으므로 에러\n# func_3(10)',
#  '_i123': "# print() : 입력 데이터를 출력하는 기능\nprint('a', 'b', 'c', sep = '\\n')",
#  '_i124': "# print() : 입력 데이터를 출력하는 기능\n# sep 매개변수에 입려 데이터를 대입하려면 매개변수명 = data\n# 첫번째 매개변수가 가변의 인자를 받는 형태이기 때문에\nprint('a', 'b', 'c', sep = '\\n')",
#  '_i125': 'def func_4(a, b = 5):\n    # 매개변수는 2개 a,b\n    #   a는 함수를 호출할때 필수 입력 공간\n    #   b는 선택 입력 공간\n    c = a ** b\n    return c',
#  'func_4': <function __main__.func_4(a, b=5)>,
#  '_i126': 'func_4(2)\n# a = 2\n# b= 5\n# c = 2**5\n# 32를 되돌려준다.',
#  '_126': 32,
#  '_i127': 'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4',
#  '_127': 16,
#  '_i128': 'func_4(2, 4)\n# a = 2\n# b = 5\n# b = 4\n# c = 2 ** 4\n# 16',
#  '_128': 16,
#  '_i129': '# 모든 영역에서 사용할 수 있는 변수의 목록 확인\nglobals()'}

# %%
text_a
# Out:
# 'APPLE'

# %%
globals()['text_a']
# Out:
# 'APPLE'

# %%
# 반복문을 이용해서 전역변수를 생성
for i in range(3, 10, 2):
    # globals() 함수를 이용하여 전역 변수 생성
    globals()[ f'a{i}'] = i

# %%
a3
# Out:
# 3

# %%
a5
# Out:
# 5

# %%
a7
# Out:
# 7

# %%
a9
# Out:
# 9

# %%
# 지역 변수 확인
def func_5(input_a, input_b):
    func_res = input_a + input_b
    return func_res

res_3 = func_5(20, 1)

# %%
print(res_3)
# func_res, input_a 지역 변수이므로 전역에서는 사용이 불가능
# print(func_res)
# print(input_a)
# Out:
# 21
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 2
#       1 print(res_3)
# ----> 2 print(func_res)
#       3 print(input_a)
#
# NameError: name 'func_res' is not defined

# %%
# 변수 생성
a = b = c = 10
print(a, b, c)
# Out:
# 10 10 10

# %%
d, e, f = 3, 'A', True
print(d, e, f)
# Out:
# 3 A True

# %%
# return data기 2개 이상인 경우
def func_6(a, b) :
    c = a + b
    d = a - b
    return c, d

# %%
func_6(10, 3)
# Out:
# (13, 7)

# %%
res_4 = func_6(10, 3)
res_4
# Out:
# (13, 7)

# %%
res_5, res_6 = func_6(10, 3)

# %%
print(res_5)
print(res_6)
# Out:
# 13
# 7

# %%
# 인자의 개수가 가변인 경우
def func_7( *args ):
    # args의 타입??
    print(type(args))
    # 인자들의 누적 합 구해서 되돌려주는 기능
    # 합계 초깃값 지정
    result = 0
    # args의 원소의 개수만큼 반복 실행하는 반복문 생성
    for i in args:
        # i는 args의 원소들이 각각 대입
        result += i
    # return은 값을 되돌려주고 함수를 종료
    return result

# %%
func_7(1, 2, 3, 4, 5)
# Out:
# <class 'tuple'>
# 15

# %%
def func_8(args):
    result = 0
    for i in args:
        result += i
    return result

# %%
func_8([1, 2, 3, 4, 5])
# Out:
# 15

# %%
# func_7() 함수를 호출하는데 입력 데이터가 리스트인 경우
func_7(*[1,2,3,4,5])
# Out:
# <class 'tuple'>
# 15

# %%
# 인자의 개수가 가변인 매개변수와 개수가 1개인 매개변수가 존재하는 함수
def func_9(*args, data):
    result = 0
    # data가 1이라면 누적합을 되돌려주고
    if data == 1:
        result = 0
        for i in args :
             result += i
    # data가 0이라면 누적곱을 되돌려준다.
    if data == 0 :
        result = 1
        for i in args:
            result *= i
    return result

# %%
func_9(1,2,3,4,5, data = 1)
# Out:
# 15

# %%
# 매개변수에 기본값이 설정이 되어있는 함수
def func_10(a, b = 2, c = 3):
    # 매개변수는 3개 : a는 필수 입력 / b,c는 선택 입력
    # 인자의 개수가 1개, 2개, 3개 모두 호출이 가능
    result = (a + b) ** c
    return result

# %%
print(func_10(3))
print(func_10(5, 1))
print(func_10(3, 1, 1))
# Out:
# 125
# 216
# 4

# %%
# func_10에서 b 매개변수는 기본값을 사용하고 c의 매개변수에는 새로운 입력값 대임
func_10(3, c = 2)
# Out:
# 25

# %%
# 함수를 생성시 매개변수의 기본값을 설정하려면 가장 위의 매개변수붜 기본값을 설정
# 증긴의 매개변수에만 기본값을 설정하면 에러가 발생
def func_11(a, b = 2, c):
    result = a + b + c
    return result
# Out:
#   Cell In[184], line 2
#     def func_11(a, b = 2, c):
#                           ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# ### 연습
#     - 함수를 생성
#         - 매개변수 2개
#             - _datas : 인자의 개수가 가변인 매개변수
#             - _type : 기본값이 설정('max')
#         - _type이 'max'라면 _datas들 중 가장 큰 값을 되돌려준다.
#         - _type이 'min'이라면 _datas들 중 가장 작은 값을 되돌려준다.
#         - _type이 'mean'이라면 _datas 들의 평균을 되돌려준다.
#         - 위에 3가지의 경우가 아니라면 "_type이 맞지 않습니다"를 되돌려준다.

# %%
def func_100(*_datas, _type = 'max'):
    if _type == 'max' :
        return max(_datas)
    elif _type == 'min' :
        return min(_datas)
    elif _type == 'mean':
        return sum(_datas)/len(_datas)
    else :
        return "_type이 맞지 않습니다."

# %%
func_100(1,2,3,4,5,6, _type ='mean')
# Out:
# 3.5

# %%
def func_11(*_datas, _type='max'):
    # _type의 데이터가 어떤것인가?
    if _type == 'max':
        # _datas 들 중 가장 큰 값을 되돌려준다.
        return max(_datas)
    if _type == 'min':
        return min(_datas)
    if _type == 'mean':
        return sum(_datas) / len(_datas)
    return " _type이 맞지 않습니다."

# %%
def func_12(*_datas, _type='max') :
    if _type == 'max':
        result = max(_datas)
    elif _type == 'min':
        result = min(_datas)
    elif _type == 'mean':
        result = sum(_datas) / len(_datas)
    else:
        result = '_type이 맞지 않습니다.'
    return result

# %%
func_11(1,2,3,4,5)
# Out:
# 5

# %%
func_11(1,2,3,4,5, _type='min')
# Out:
# 1

# %%
func_11(1,2,3,4,5, _type='mean')
# Out:
# 3.0

# %%
func_12(1,2,3,4,5, _type='mean')
# Out:
# 3.0

# %%
func_12(1,2,3,4,5, _type='sum')
# Out:
# '_type이 맞지 않습니다.'
